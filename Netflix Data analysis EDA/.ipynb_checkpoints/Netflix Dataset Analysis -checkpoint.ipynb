# %%
import pandas as pd
import seaborn as sns

# %%
#read_dataset
data =pd.read_csv(r"C:\Users\HP\Desktop\Netflix Data analysis\8. Netflix Dataset.csv")
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # PRE PROCESSING

# %% [markdown]
# # Dupilcate Values

# %%
#handling Duplicate datas

data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace= True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# # Null value hanndling

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# Ploting null value heat map

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # NULL VALUE REPLACEING

# %%
data1= data.fillna({'Director': 'Mr: MOUNO',
                     'Cast': 'MOUNO',
                      'Country': ' USA',
                       'Release_Date': '1 January 2022'})

# %%
data1.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          7
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %% [markdown]
# # Perticular element fetch

# %%
data1[data1['Director'].str.contains('Christopher Nolan')]
# Out:
#      Show_Id Category      Title           Director  \
# 2979   s2980    Movie  Inception  Christopher Nolan
#
#                                                    Cast  \
# 2979  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
#
#                             Country     Release_Date Rating Duration  \
# 2979  United States, United Kingdom  January 1, 2020  PG-13  148 min
#
#                                                  Type  \
# 2979  Action & Adventure, Sci-Fi & Fantasy, Thrillers
#
#                                             Description
# 2979  In this mind-bending sci-fi thriller, a man ru...

# %% [markdown]
# # Date data type replace

# %%
data1.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#inserting new caluum with valud date formate

# %%
data1['date']=pd.to_datetime(data['Release_Date'])

# %%
data1.drop("Release_Date", axis='columns')
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0             Mr: MOUNO  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data1['date'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: date, dtype: int64

# %% [markdown]
# # BAR CHART (ACCORDING Years)

# %%
data1['date'].dt.year.value_counts().plot(kind='bar')


# Most movies released in 2019
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Movies and Tv Shows

# %%
data1.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(data1['Category'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
data1
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0             Mr: MOUNO  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
#                More movies than Tv showes

# %% [markdown]
# # Movies in 2016

# %%
data1['Year']= data1['date'].dt.year

# %%
data1[(data1['Category'] == 'Movie') & (data1['Year'] == 2016)]
# Out:
#      Show_Id Category                    Title  \
# 1         s2    Movie                    07:19
# 25       s26    Movie                 (T)ERROR
# 35       s36    Movie                #Rucker50
# 59       s60    Movie          1000 Rupee Note
# 62       s63    Movie               13 Cameras
# ...      ...      ...                      ...
# 7715   s7714    Movie  Yo-Kai Watch: The Movie
# 7716   s7715    Movie              Yoga Hosers
# 7728   s7727    Movie             You Carry Me
# 7739   s7738    Movie              Young Tiger
# 7772   s7771    Movie                  Zinzana
#
#                                     Director  \
# 1                          Jorge Michel Grau
# 25    Lyric R. Cabral, David Felix Sutcliffe
# 35                     Robert McCullough Jr.
# 59                            Shrihari Sathe
# 62                            Victor Zarcoff
# ...                                      ...
# 7715                             Mark Risley
# ...

# %% [markdown]
# # Only Brazilian Tv showes

# %%
data1[(data1['Category'] == 'TV Show') & (data1['Country'] == 'Brazil')]['Title']
# Out:
# 0                                      3%
# 218                       A Queen Is Born
# 322                   Afronta! Facing It!
# 531               Anitta: Made In Honório
# 989                            Blood Pact
# 1052                               Borges
# 1115                          Brotherhood
# 1626                Dating Around: Brazil
# 1905                       Earth to Luna!
# 2486               Good Morning, Verônica
# 3416                         Kissing Game
# 3814                      Lugar de Mulher
# 4233                 Most Beautiful Thing
# 4369                          Mystery Lab
# 4502                     Nobody's Looking
# 4611                           Omniscient
# 5121                            Reality Z
# 5363                            Samantha!
# 5636                             Sintonia
# 5747                             Spectros
# 5892                          Super Drags
# 6125    The Beginning of Life: The Series
# ...

# %% [markdown]
# # Top 5 countries producing movies

# %%
data1['Country'].value_counts().head(5).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # And or operator

# %%
data1[(data1['Category'] == 'Movie') & (data1['Type'] == 'Documentaries') | (data1['Country'] == 'Brazil')]
# Out:
#      Show_Id Category                                              Title  \
# 0         s1  TV Show                                                 3%
# 25       s26    Movie                                           (T)ERROR
# 56       s57    Movie           100 Years: One Woman's Fight for Justice
# 66       s67    Movie                                               13TH
# 70       s71    Movie                              14 Minutes from Earth
# ...      ...      ...                                                ...
# 7618   s7617    Movie                 Why We Fight: The Battle of Russia
# 7649   s7648    Movie                                      Without Gorky
# 7681   s7680    Movie                    WWII: Report from the Aleutians
# 7694   s7693    Movie  Ya no estoy aquí: Una conversación entre Guill...
# 7758   s7757  TV Show                                                 Z4
#
#                                                Director  \
# ...

# %% [markdown]
# # Unique rating

# %%
data1['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Movies of america with TV-14 rating

# %%
data1[(data1['Category'] == 'Movie') & (data1['Country'] == 'United States')]
# Out:
#      Show_Id Category                       Title         Director  \
# 3         s4    Movie                           9      Shane Acker
# 4         s5    Movie                          21   Robert Luketic
# 7         s8    Movie                         187   Kevin Reynolds
# 10       s11    Movie                        1922     Zak Hilditch
# 14       s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7773   s7772    Movie                        Zion       Floyd Russ
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
# 7783   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %%
data1[(data1['Category'] == 'Movie') & (data1['Country'] == 'United States')& (data1['Rating'] == 'TV-14') ]
# Out:
#      Show_Id Category                                     Title  \
# 33       s34    Movie                              #realityhigh
# 47       s48    Movie                             1 Mile to You
# 56       s57    Movie  100 Years: One Woman's Fight for Justice
# 184     s185    Movie    A Haunting at Silver Falls: The Return
# 223     s224    Movie                             A Secret Love
# ...      ...      ...                                       ...
# 7563   s7562    Movie                        What Still Remains
# 7571   s7570    Movie               What Would Sophia Loren Do?
# 7588   s7587    Movie                         When We First Met
# 7644   s7643    Movie                                  Wish Man
# 7664   s7663    Movie                                   Work It
#
#               Director                                               Cast  \
# 33    Fernando Lebrija  Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...

# %%
data1[(data1['Category'] == 'Movie') & (data1['Country'] == 'United States')& (data1['Rating'] == 'TV-14') ].count()
# Out:
# Show_Id         200
# Category        200
# Title           200
# Director        200
# Cast            200
# Country         200
# Release_Date    200
# Rating          200
# Duration        200
# Type            200
# Description     200
# date            200
# Year            200
# dtype: int64

# %% [markdown]
# # mamximum Duration movies

# %%
data1.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data1.Duration.unique().dtype
# Out:
# dtype('O')

# %%
data1[['Minuties', 'unit' ]]=data1.Duration.str.split(' ',expand= True)
data1
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0             Mr: MOUNO  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data1.Minuties.max()
# Out:
# '99'

# %%
data1.Minuties.min()
# Out:
# '1'

# %%
data1[(data1['Category'] == 'Movie') &  (data1['Minuties'] == data1.Minuties.max()) ]
# Out:
#      Show_Id Category                                        Title  \
# 27       s28    Movie                                       #Alive
# 33       s34    Movie                                 #realityhigh
# 42       s43    Movie                  Çok Filim Hareketler Bunlar
# 121     s122    Movie                               50 First Dates
# 147     s148    Movie      A Babysitter's Guide to Monster Hunting
# ...      ...      ...                                          ...
# 7449   s7448    Movie                                          VS.
# 7527   s7526    Movie                        Welcome Mr. President
# 7559   s7558    Movie                         What Keeps You Alive
# 7638   s7637    Movie  Winter on Fire: Ukraine's Fight for Freedom
# 7784   s7783    Movie                                         Zozo
#
#                Director                                               Cast  \
# 27               Cho Il                           Yoo Ah-in, Park Shin-hye
# ...

# %%
data1[(data1['Category'] == 'TV Show') &  (data1['Minuties'] == data1.Minuties.min()) ]
# Out:
#      Show_Id Category                  Title              Director  \
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983             Mr: MOUNO
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09             Mr: MOUNO
# 26       s27  TV Show               (Un)Well             Mr: MOUNO
# ...      ...      ...                    ...                   ...
# 7768   s7767  TV Show           Zig & Sharko             Mr: MOUNO
# 7769   s7768  TV Show     Zindagi Gulzar Hai             Mr: MOUNO
# 7777   s7776  TV Show             Zoids Wild             Mr: MOUNO
# 7781   s7780  TV Show              Zona Rosa             Mr: MOUNO
# 7787   s7786  TV Show  Zumbo's Just Desserts             Mr: MOUNO
#
#                                                    Cast  \
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...

# %% [markdown]
# # Sort By year

# %%
data1.sort_values(by='Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five             Mr: MOUNO
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki             Mr: MOUNO
# 3492   s3493  TV Show           La Familia P. Luche             Mr: MOUNO
# 3946   s3947  TV Show                         Maron             Mr: MOUNO
# 5138   s5138  TV Show                  Red vs. Blue             Mr: MOUNO
# 6066   s6066  TV Show  The Adventures of Figaro Pho             Mr: MOUNO
#
#                                                    Cast        Country  \
# ...

# %%
data1.sort_values(by='Year', ascending = False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                Mr: MOUNO
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                Mr: MOUNO
# 3492   s3493  TV Show           La Familia P. Luche                Mr: MOUNO
# 3946   s3947  TV Show                         Maron                Mr: MOUNO
# 5138   s5138  TV Show                  Red vs. Blue                Mr: MOUNO
# 6066   s6066  TV Show  The Adventures of Figaro Pho                Mr: MOUNO
#
# ...
